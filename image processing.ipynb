# %% [markdown]
# <a href="https://colab.research.google.com/github/KalagaMadhu/SDC/blob/main/image%20processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
img =cv2.imread('/content/drive/MyDrive/edgeflower.jpg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
cv2_imshow(gray)
print(gray)
print(img)
print(gray.shape)
gray2=70-gray
cv2_imshow(gray2)
print(gray2)
# Out:
# <PIL.Image.Image image mode=RGB size=717x706>
# <PIL.Image.Image image mode=L size=717x706>
# [[ 65  63  62 ... 101  20   0]
#  [ 64  62  62 ... 102  21   0]
#  [ 61  61  62 ... 101  20   0]
#  ...
#  [  7   9   9 ...  69  15   2]
#  [  8   7   8 ...  69  16   2]
#  [  8   7   8 ...  69  16   2]]
# [[[ 26  70  69]
#   [ 24  68  67]
#   [ 23  67  66]
#   ...
#   [ 87 102 105]
#   [  9  21  21]
#   [  0   0   1]]
#
#  [[ 25  69  68]
#   [ 23  67  66]
#   [ 23  67  66]
#   ...
#   [ 88 103 106]
#   [ 10  22  22]
#   [  0   0   1]]
#
#  [[ 22  66  65]
#   [ 22  66  65]
#   [ 23  67  66]
#   ...
#   [ 87 102 105]
#   [  9  21  21]
#   [  0   0   1]]
#
#  ...
#
#  [[  5   7   8]
#   [  7   9  10]
#   [  7   9  10]
#   ...
#   [ 39  61  96]
#   [  0  10  32]
#   [  0   0   8]]
#
#  [[  8   7   9]
#   [  7   6   8]
#   [  6   8   9]
#   ...
#   [ 37  62  96]
#   [  0  11  32]
#   [  0   0   8]]
#
#  [[  8   7   9]
#   [  7   6   8]
#   [  6   8   9]
#   ...
#   [ 37  62  96]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gray2=30-gray
cv2_imshow(gray2)
print(gray2)
# Out:
# <PIL.Image.Image image mode=L size=717x706>
# [[221 223 224 ... 185  10  30]
#  [222 224 224 ... 184   9  30]
#  [225 225 224 ... 185  10  30]
#  ...
#  [ 23  21  21 ... 217  15  28]
#  [ 22  23  22 ... 217  14  28]
#  [ 22  23  22 ... 217  14  28]]

# %%
gray2=10*gray
cv2_imshow(gray2)
print(gray2)
# Out:
# <PIL.Image.Image image mode=L size=717x706>
# [[138 118 108 ... 242 200   0]
#  [128 108 108 ... 252 210   0]
#  [ 98  98 108 ... 242 200   0]
#  ...
#  [ 70  90  90 ... 178 150  20]
#  [ 80  70  80 ... 178 160  20]
#  [ 80  70  80 ... 178 160  20]]
